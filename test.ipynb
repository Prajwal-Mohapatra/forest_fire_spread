# %%
import os

def count_tiff_files(directory_path):
    """Counts the number of TIFF files in the given directory and subdirectories."""
    tiff_count = 0
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.lower().endswith('.tif') or file.lower().endswith('.tiff'):
                tiff_count += 1
    return tiff_count

# Example usage: Replace with your directory path
# For stacked datasets:
stacked_path = 'datasets/dataset_stacked'  # Relative or absolute path
num_stacked_tiffs = count_tiff_files(stacked_path)
print(f"Number of stacked TIFF files: {num_stacked_tiffs}")

# For fire masks:
fire_mask_path = 'datasets/dataset_unstacked/fire_mask'
num_fire_masks = count_tiff_files(fire_mask_path)
print(f"Number of fire mask TIFF files: {num_fire_masks}")

# If you have patch extraction logs, manually note the number of patches (e.g., from training_log.csv or notebooks)
# Out:
# Number of stacked TIFF files: 59
# Number of fire mask TIFF files: 61

# %%
import glob
import rasterio
import numpy as np

def count_positive_fire_pixels(fire_mask_path):
    """Counts the number of positive (fire) pixels (>0) in a single fire mask TIFF file."""
    with rasterio.open(fire_mask_path) as src:
        fire_mask = src.read(1)  # Read the first band
        total_pixels = fire_mask.size  # Total pixels in the raster
        positive_pixels = np.sum(fire_mask > 0)  # Count pixels greater than 0
        imbalance_ratio = (positive_pixels / total_pixels) * 100 if total_pixels > 0 else 0
        return positive_pixels, total_pixels, imbalance_ratio

# Example usage: Specify your fire mask file path manually
file_path_base = 'datasets/dataset_unstacked/fire_mask/'  # Replace with actual path

test_files = sorted(glob.glob(os.path.join(file_path_base, 'fire_mask_2016_*.tif')))

# print(test_files)

for files in test_files:
    positive, total, ratio = count_positive_fire_pixels(files)
    print(f"File: {files}")
    print(f"Positive fire pixels: {positive}")
    print(f"Total pixels: {total}")
    print(f"Fire percentage (imbalance): {ratio:.6f}%")

# To check multiple files: Repeat for a few (e.g., 2016_04_05.tif, 2016_05_01.tif) and average the ratios
# Out:
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_01.tif
# Positive fire pixels: 70
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000057%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_02.tif
# Positive fire pixels: 89
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000072%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_03.tif
# Positive fire pixels: 67
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000054%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_04.tif
# Positive fire pixels: 33
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000027%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_05.tif
# Positive fire pixels: 29
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000024%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_06.tif
# Positive fire pixels: 64
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000052%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_07.tif
# Positive fire pixels: 133
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000108%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_08.tif
# Positive fire pixels: 350
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000284%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_09.tif
# Positive fire pixels: 251
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000203%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_10.tif
# Positive fire pixels: 390
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000316%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_11.tif
# Positive fire pixels: 730
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000592%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_12.tif
# Positive fire pixels: 504
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000409%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_13.tif
# Positive fire pixels: 896
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000726%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_14.tif
# Positive fire pixels: 957
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000776%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_15.tif
# Positive fire pixels: 654
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000530%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_16.tif
# Positive fire pixels: 406
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000329%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_17.tif
# Positive fire pixels: 160
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000130%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_18.tif
# Positive fire pixels: 190
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000154%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_19.tif
# Positive fire pixels: 225
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000182%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_20.tif
# Positive fire pixels: 370
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000300%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_21.tif
# Positive fire pixels: 642
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000520%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_22.tif
# Positive fire pixels: 326
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000264%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_23.tif
# Positive fire pixels: 1002
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000812%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_24.tif
# Positive fire pixels: 2608
# Total pixels: 123370267
# Fire percentage (imbalance): 0.002114%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_25.tif
# Positive fire pixels: 2030
# Total pixels: 123370267
# Fire percentage (imbalance): 0.001645%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_26.tif
# Positive fire pixels: 3377
# Total pixels: 123370267
# Fire percentage (imbalance): 0.002737%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_27.tif
# Positive fire pixels: 3122
# Total pixels: 123370267
# Fire percentage (imbalance): 0.002531%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_28.tif
# Positive fire pixels: 2918
# Total pixels: 123370267
# Fire percentage (imbalance): 0.002365%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_29.tif
# Positive fire pixels: 2930
# Total pixels: 123370267
# Fire percentage (imbalance): 0.002375%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_04_30.tif
# Positive fire pixels: 1315
# Total pixels: 123370267
# Fire percentage (imbalance): 0.001066%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_01.tif
# Positive fire pixels: 1026
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000832%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_02.tif
# Positive fire pixels: 717
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000581%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_03.tif
# Positive fire pixels: 102
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000083%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_04.tif
# Positive fire pixels: 87
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000071%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_05.tif
# Positive fire pixels: 4
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000003%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_06.tif
# Positive fire pixels: 16
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000013%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_07.tif
# Positive fire pixels: 26
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000021%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_08.tif
# Positive fire pixels: 23
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000019%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_09.tif
# Positive fire pixels: 25
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000020%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_10.tif
# Positive fire pixels: 15
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000012%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_11.tif
# Positive fire pixels: 4
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000003%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_12.tif
# Positive fire pixels: 16
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000013%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_13.tif
# Positive fire pixels: 18
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000015%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_14.tif
# Positive fire pixels: 53
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000043%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_15.tif
# Positive fire pixels: 74
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000060%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_16.tif
# Positive fire pixels: 133
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000108%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_17.tif
# Positive fire pixels: 162
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000131%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_18.tif
# Positive fire pixels: 138
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000112%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_19.tif
# Positive fire pixels: 64
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000052%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_20.tif
# Positive fire pixels: 65
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000053%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_21.tif
# Positive fire pixels: 44
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000036%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_22.tif
# Positive fire pixels: 38
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000031%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_23.tif
# Positive fire pixels: 21
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000017%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_24.tif
# Positive fire pixels: 1
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000001%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_25.tif
# Positive fire pixels: 6
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000005%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_26.tif
# Positive fire pixels: 13
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000011%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_27.tif
# Positive fire pixels: 31
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000025%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_28.tif
# Positive fire pixels: 10
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000008%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_29.tif
# Positive fire pixels: 0
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000000%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_30.tif
# Positive fire pixels: 0
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000000%
# File: datasets/dataset_unstacked/fire_mask/fire_mask_2016_05_31.tif
# Positive fire pixels: 6
# Total pixels: 123370267
# Fire percentage (imbalance): 0.000005%
