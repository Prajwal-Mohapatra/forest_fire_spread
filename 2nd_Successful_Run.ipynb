# %%
# !pip install -q keras-nightly --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.5 MB/s eta 0:00:0000:0100:01

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
import tensorflow as tf
import numpy as np
# Out:
# 2025-07-08 08:28:46.965612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751963327.214982      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751963327.291840      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !git clone https://github.com/Prajwal-Mohapatra/forest_fire_ml
# Out:
# Cloning into 'forest_fire_ml'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 155 (delta 61), reused 153 (delta 59), pack-reused 0 (from 0)
# Receiving objects: 100% (155/155), 426.22 KiB | 20.30 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# Filtering content: 100% (2/2), 690.44 MiB | 87.18 MiB/s, done.

# %%
# %cd /kaggle/working/forest_fire_ml
# !git pull
# Out:
# /kaggle/working/forest_fire_ml
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 712 bytes | 712.00 KiB/s, done.
# From https://github.com/Prajwal-Mohapatra/forest_fire_ml
#    11306b3..1e262e3  main       -> origin/main
# Updating 11306b3..1e262e3
# Fast-forward
#  .gitignore | 98 +++++++++++++++++++++++++++++++++++++++++-----------------------------------------
#  1 file changed, 49 insertions(+), 49 deletions(-)

# %%
# !pip install rasterio --quiet

# !python run_pipeline.py --mode train --data_dir /kaggle/input/stacked-fire-probability-prediction-dataset/dataset_stacked
# Out:
# ✅ Environment setup complete!
# 🚀 Pipeline started at 2025-07-08 08:44:31.025430
# 🔥 Starting Fire Prediction Model Training...
# Configuration: {'patch_size': 256, 'batch_size': 8, 'n_patches_per_img': 30, 'epochs': 50, 'learning_rate': 0.0001, 'fire_focus_ratio': 0.8}
# 2025-07-08 08:44:31.687197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751964271.708177     272 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751964271.714442     272 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !git config --global user.email "swayam1223@gmail.com"
# !git config --global user.name "Swayam2004"
# !git commit -am "second training session completed, with keras 3, tensorflow backend"

# !git push
# Out:
# Username for 'https://github.com':
